# %% [markdown]
# # Chest X-Ray Multi-Modal System — Colab Runner
#
# Runtime: **T4 GPU**, 16 GB VRAM. Other cells (clone, install, download, launch demo) are added in Phase 6.

# %% [markdown]
# ## Kaggle authentication
#
# Before running `data/download.py`, expose your Kaggle credentials so `kagglehub` can pull MIMIC-CXR.
#
# Add `KAGGLE_USERNAME` and `KAGGLE_KEY` in Colab's **Secrets** panel (key icon in the left sidebar) first, then run the cell below.

# %%
import os
from google.colab import userdata

os.environ["KAGGLE_USERNAME"] = userdata.get("KAGGLE_USERNAME")
os.environ["KAGGLE_KEY"] = userdata.get("KAGGLE_KEY")
print("Kaggle creds set for user:", os.environ["KAGGLE_USERNAME"])
